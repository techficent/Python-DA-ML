# %% [markdown]
# # Load the dataset 'drug companies.xlsx'. Set 'Rank by 2020 Revenue' as the index column

# %% [markdown]
# # Show the list of columns from this loaded dataset

# %% [markdown]
# # Show the index of the dataset

# %% [markdown]
# # Find the missing values count in each column

# %% [markdown]
# # Print first 5 rows of this dataset for sampling

# %% [markdown]
# # Print the Company Name and Symbol of companies ranked 4 to 8 (both included) as per 2020 Revenue

# %% [markdown]
# # Print the 2020 Revenue amount for companies ranked 11-15 (both included) as per 2020 revenue

# %% [markdown]
# # Print the companany name and symbol for all companies with 2020 revenue equal to or greater than average 2020 revenue amount

# %% [markdown]
# # Print the sum of 2020 revenue for companies based in USA, UK or Denmark

# %% [markdown]
# # Find the average market cap value for companies grouped by country

# %% [markdown]
# # Print the name and symbol of companies whose ranky by 2020 Revenue and ranky by Market Cap Value is exactly the same
