# %%
import pickle

# %%
f1 = open("model.pkl", "rb")

model = pickle.load(f1)

f1.close()

# %%
import pandas as pd
data_df = pd.read_csv("Univariate_data.csv")


model.predict( data_df )
# Out:
# array([[32.70432487],
#        [24.40882029],
#        [77.97372783],
#        [51.11150959],
#        [63.38296607]])
