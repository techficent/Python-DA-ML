# %% [markdown]
# ## Objective : Prediction of Close Price values based on Open price values

# %%
import pandas as pd

link = "https://raw.githubusercontent.com/techficent/Python-DA-ML/main/timeseries_dummy.csv" 

df = pd.read_csv( link,index_col='Date', parse_dates=['Date'] )

df
# Out:
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 2011-07-18  18.567362  18.662239  18.500950  18.633776  12.477077   36651480.0
# 2011-07-19  18.643265  19.003796  18.614801        NaN  12.667668   36521627.0
# 2011-07-20  18.899431  18.975332  18.757116  18.880455  12.642256   37286409.0
# 2011-07-21  18.984819  19.165085  18.956356        NaN  12.769313   46844292.0
# 2011-07-22  19.060720        NaN  18.946869  19.041746  12.750255   27217020.0
# 2011-07-25  18.861481        NaN  18.795067  18.795067  12.585078          NaN
# 2011-07-26  18.833017  18.880455  18.567362  18.624289  12.470728   40813410.0
# 2011-07-27  18.529411  18.614801  18.273245  18.311195  12.261080   42527424.0
# 2011-07-28        NaN  18.614801  18.263758  18.368120  12.299200   62017992.0
# 2011-07-29  18.225805        NaN  18.074003  18.263758  12.229320   73232131.0
# 2011-08-01  18.444023  18.462997  17.789373  18.036053  12.076848          NaN
# ...

# %%
df.fillna(method='ffill', inplace=True)

df
# Out:
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 2011-07-18  18.567362  18.662239  18.500950  18.633776  12.477077   36651480.0
# 2011-07-19  18.643265  19.003796  18.614801  18.633776  12.667668   36521627.0
# 2011-07-20  18.899431  18.975332  18.757116  18.880455  12.642256   37286409.0
# 2011-07-21  18.984819  19.165085  18.956356  18.880455  12.769313   46844292.0
# 2011-07-22  19.060720  19.165085  18.946869  19.041746  12.750255   27217020.0
# 2011-07-25  18.861481  19.165085  18.795067  18.795067  12.585078   27217020.0
# 2011-07-26  18.833017  18.880455  18.567362  18.624289  12.470728   40813410.0
# 2011-07-27  18.529411  18.614801  18.273245  18.311195  12.261080   42527424.0
# 2011-07-28  18.529411  18.614801  18.263758  18.368120  12.299200   62017992.0
# 2011-07-29  18.225805  18.614801  18.074003  18.263758  12.229320   73232131.0
# 2011-08-01  18.444023  18.462997  17.789373  18.036053  12.076848   73232131.0
# ...

# %% [markdown]
# ## Drop columns that are not relevant to our task

# %%
df.drop(columns=['Volume', 'Adj Close'], inplace=True)

df
# Out:
#                  Open       High        Low      Close
# Date
# 2011-07-18  18.567362  18.662239  18.500950  18.633776
# 2011-07-19  18.643265  19.003796  18.614801  18.633776
# 2011-07-20  18.899431  18.975332  18.757116  18.880455
# 2011-07-21  18.984819  19.165085  18.956356  18.880455
# 2011-07-22  19.060720  19.165085  18.946869  19.041746
# 2011-07-25  18.861481  19.165085  18.795067  18.795067
# 2011-07-26  18.833017  18.880455  18.567362  18.624289
# 2011-07-27  18.529411  18.614801  18.273245  18.311195
# 2011-07-28  18.529411  18.614801  18.263758  18.368120
# 2011-07-29  18.225805  18.614801  18.074003  18.263758
# 2011-08-01  18.444023  18.462997  17.789373  18.036053
# 2011-08-02  17.979128  18.462997  17.210627  17.210627
# 2011-08-03  17.096773  17.239088  17.210627  17.106262
# 2011-08-04  16.869070  17.039848  16.451612  16.470589

# %% [markdown]
# # Data exploration
#
# ### Find missing values, statistical description, info, etc to determine the quality of data & decide if any cleaning is necessary

# %%
df.describe()
# Out:
#             Open       High        Low      Close
# count  14.000000  14.000000  14.000000  14.000000
# mean   18.394551  18.576172  18.172269  18.232583
# std     0.667964   0.659885   0.753948   0.772992
# min    16.869070  17.039848  16.451612  16.470589
# 25%    18.280360  18.500948  17.860531  18.092979
# 50%    18.548386  18.638520  18.387097  18.496205
# 75%    18.854365  18.996680  18.721537  18.754744
# max    19.060720  19.165085  18.956356  19.041746

# %%
df.corr()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.976465  0.947149  0.959447
# High   0.976465  1.000000  0.918557  0.924967
# Low    0.947149  0.918557  1.000000  0.992344
# Close  0.959447  0.924967  0.992344  1.000000

# %% [markdown]
# ### If I calculate slope and y intercept for the PERFECT trendline, I can use trendline to make prediction of y values in future!

# %%
import plotly_express as pe

for column in ['Open', 'Low', 'High'] :
    display (   pe.scatter(x=column, y='Close', data_frame =df, trendline='ols'  ) )

# %%
# missing values count?

df.isna().sum()
# Out:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
import sklearn as sk

sk.__version__
# Out:
# '1.1.1'

# %% [markdown]
# # Steps for supervised learning
# ### 1) Loading the data
#
# ### 2) exploring the data
#
# ### 3) Clean the data ---> renaming of axis, filling missing values, SCALING VALUES, ENCODING, etc
#
# ### 4) separating the data for training & testing!!!!!
#
# ### 5) Select the algorithm & train the model!
#
# ### 6) test the model
#
#
# ############# DEPLOYMENT OF THE MODEL ############################

# %% [markdown]
# ### divide the data into features & labels

# %%
feature = df [['Open','High','Low']].copy()

label  = df[['Close']].copy()

# %% [markdown]
# ### Separate features & labels (both) into training set & testing test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(feature, label,  test_size=0.2, random_state=10  )

# %%
from sklearn.linear_model  import LinearRegression


model = LinearRegression( )


model.fit(   X_train,   y_train  )
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 0.3082587 , -0.21738432,  0.93288291]])

# %%
model.intercept_
# Out:
# array([-0.32429869])

# %%
predicted_ans =    model.predict(  X_test  )


predicted_df  =  pd.DataFrame(    predicted_ans       )


predicted_df
# Out:
#            0
# 0  19.045808
# 1  18.387786
# 2  17.253923

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predicted_ans)



mse
# Out:
# 0.018337185882247007

# %% [markdown]
# ### Below cell contains code to concatenate feature, prediction & actual close price columns together

# %%
X_test.reset_index(drop=True,inplace=True)
y_test.reset_index(drop=True,inplace=True)

final_df = pd.concat(  [X_test,predicted_df, y_test ],axis=1  )

final_df.rename(columns={0 : "Predicted Close Price", "Close" : "Actual Close Price"}, inplace=True)

final_df
# Out:
#         Open       High        Low  Predicted Close Price  Actual Close Price
# 0  18.984819  19.165085  18.956356              19.045808           18.880455
# 1  18.529411  18.614801  18.273245              18.387786           18.311195
# 2  17.096773  17.239088  17.210627              17.253923           17.106262

# %%
y_test
# Out:
#        Close
# 0  18.880455
# 1  18.311195
# 2  17.106262

# %%
data_df = pd.read_csv("Multivariate_data.csv")


data_df
# Out:
#     Open   High    Low
# 0  30.21  33.41  29.42
# 1  23.45  25.21  23.20
# 2  67.10  68.20  66.90
# 3  45.21  46.20  44.20
# 4  55.21  56.71  55.01

# %% [markdown]
# ### Making prediction on new data

# %%
model.predict( data_df )
# Out:
# array([[29.17080165],
#        [23.06699258],
#        [67.94411602],
#        [44.80234609],
#        [55.68468813]])
